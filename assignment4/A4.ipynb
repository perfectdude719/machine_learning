# %% [markdown]
# Installing Libraries

# %%
# !pip install pandas
# !pip install numpy matplotlib seaborn
# !pip install scikit-learn
# !pip install plotly
# !pip install nbformat --upgrade
# Out:
# Requirement already satisfied: pandas in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (2.2.0)
# Requirement already satisfied: matplotlib in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (3.9.4)
# Requirement already satisfied: seaborn in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: plotly in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from plotly) (24.1)
# Requirement already satisfied: nbformat in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\term 9\artificail intellegnce\repo\machine_learning\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# Load Dataset

# %%
# Load the dataset
file_path = r"C:\Term 9\Artificail Intellegnce\REPO\machine_learning\assignment4\data.csv"
data = pd.read_csv(file_path)

# Display the first few rows
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# Preprocessing and data handling
# - missing data fill
# -

# %%
# Preprocessing: Remove any non-numeric columns (e.g., 'id', 'diagnosis')
if 'id' in data.columns:
    data = data.drop(columns=['id'])
if 'diagnosis' in data.columns:
    data = data.drop(columns=['diagnosis'])

# Check for missing values
print(data.isnull().sum())

# If there are missing values, fill missing values with the mean
data = data.fillna(data.mean())

#Handle Outliers, Remove them (based on a threshold, e.g., 1.5 times the interquartile range)
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
data = data[~((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).any(axis=1)]

# Standardize the dataset
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Convert back to DataFrame for easier handling
data_scaled = pd.DataFrame(data_scaled, columns=data.columns)
data_scaled.head()
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.964461      0.377377        1.973596   2.108920         0.112751
# 1     0.134540      0.594978        0.225722   0.033027         2.126689
# 2     1.065623      1.211941        0.968866   1.020884        -0.930314
# 3     0.968887     -0.157666        1.022372   0.945414         0.317713
# 4     0.997102      1.393701        1.028317   0.953051        -0.768502
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0          0.650915        1.066356             1.488638       0.277054
# 1          2.239566        0.677832             0.935739       2.210386
# 2         -0.560180       -0.560181            -0.104415      -1.002217
# 3          1.229127        0.797817             1.178389       0.507899
# 4          0.399021        0.794553             0.693088       0.531946
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0               -0.756789  ...      2.413510       0.521788         2.468580
# 1                2.655183  ...      0.610898       0.607065         0.541116
# 2               -0.846630  ...      1.270617       1.626840         1.138359
# 3               -0.077988  ...      1.651581       0.454277         1.712978
# 4               -1.563363  ...      0.542758       0.521788         0.604460
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    2.665355          0.767070           0.428375         1.121869
# 1    0.511879          1.815139           1.456575         0.369659
# 2    1.280326         -0.523241          -0.524523        -0.459405
# 3    1.732891          0.539659           3.248023         1.244971
# 4    0.449613         -0.770426          -0.177761         0.127537
#
#    concave_points_worst  symmetry_worst  fractal_dimension_worst
# 0              1.941020        0.625692                 0.333092
# 1              1.187592        0.931552                 2.854076
# 2              0.068471        0.361226                 0.400490
# 3              1.696556        2.302172                 2.027655
# 4              0.311933        0.041568                -1.336598
#
# [5 rows x 30 columns]

# %% [markdown]
# Implementing PCA

# %%
def pca(data, n_components):
    # Step 1: Compute the covariance matrix
    cov_matrix = np.cov(data.T)
    
    # Step 2: Compute eigenvalues and eigenvectors
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
    
    # Step 3: Sort eigenvectors by descending eigenvalues
    sorted_indices = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[sorted_indices]
    eigenvectors = eigenvectors[:, sorted_indices]
    
    # Step 4: Select the top n_components
    top_eigenvectors = eigenvectors[:, :n_components]
    
    # Step 5: Project the data
    reduced_data = np.dot(data, top_eigenvectors)
    return reduced_data, eigenvalues, eigenvectors

# Example: Reduce to 2 components
reduced_data, eigenvalues, eigenvectors = pca(data_scaled.values, n_components=2)
print(reduced_data[:5])
# Out:
# [[-5.92706678  3.50541662]
#  [-5.15701236 -4.1752157 ]
#  [-1.17301257  3.40849842]
#  [-6.36932678 -0.73928499]
#  [-2.78679715  0.66664918]]

# %% [markdown]
# Implementing K-means

# %%
def kmeans(data, k, max_iter=100):
    # Step 1: Randomly initialize centroids
    np.random.seed(42)
    random_indices = np.random.choice(data.shape[0], k, replace=False)
    centroids = data[random_indices]
    
    for i in range(max_iter):
        # Step 2: Assign points to nearest centroid
        distances = np.linalg.norm(data[:, None] - centroids, axis=2)
        labels = np.argmin(distances, axis=1)
        
        # Step 3: Recalculate centroids
        new_centroids = np.array([data[labels == j].mean(axis=0) for j in range(k)])
        
        # Check for convergence
        if np.all(centroids == new_centroids):
            break
        centroids = new_centroids
    
    # Compute SSE
    sse = np.sum((data - centroids[labels]) ** 2)
    return labels, centroids, sse

# Example: Cluster into 3 clusters
labels, centroids, sse = kmeans(data_scaled.values, k=3)
print(f"SSE: {sse}")
# Out:
# SSE: 7268.018136439987

# %% [markdown]
# Implementing Elbow Method

# %%
def elbow_method(data, max_k):
    sse_list = []
    for k in range(1, max_k + 1):
        _, _, sse = kmeans(data, k)
        sse_list.append(sse)
    
    # Plot the elbow curve
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, max_k + 1), sse_list, marker='o')
    plt.xlabel('Number of Clusters (k)')
    plt.ylabel('SSE')
    plt.title('Elbow Method')
    plt.show()

# Example: Apply elbow method
elbow_method(data_scaled.values, max_k=10)

# %% [markdown]
# First Experiment: K-Means on Original Data

# %%
labels, centroids, sse = kmeans(data_scaled.values, k=3)
print(f"SSE for original data: {sse}")
# Out:
# SSE for original data: 7268.018136439987

# %% [markdown]
# Second Experiment: PCA + K-Means

# %%
reduced_data, _, _ = pca(data_scaled.values, n_components=2)
labels, centroids, sse = kmeans(reduced_data, k=3)
print(f"SSE after PCA: {sse}")
# Out:
# SSE after PCA: 2688.9513662313548

# %% [markdown]
# Visualizing clusters for PCA-reduced data

# %%
def visualize_clusters(data, labels, title):
    plt.figure(figsize=(8, 5))
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', s=50)
    plt.title(title)
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.colorbar(label='Cluster')
    plt.show()

visualize_clusters(reduced_data, labels, "Clusters after PCA")

# %% [markdown]
# Validating with scikit-learn

# %%
# PCA using scikit-learn
pca_model = PCA(n_components=2)
data_reduced = pca_model.fit_transform(data_scaled)

# K-Means using scikit-learn
kmeans_model = KMeans(n_clusters=3, random_state=42)
kmeans_model.fit(data_reduced)
sklearn_labels = kmeans_model.labels_

# Visualize results
visualize_clusters(data_reduced, sklearn_labels, "Clusters using scikit-learn")
